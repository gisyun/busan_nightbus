# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
from glob import glob
import folium

# %%
#데이터 불러오기

metro_matrix = pd.read_excel('./2022_부산광역시지하철_이용객수요(OD).xlsx', sheet_name=['Sheet2'])
metro_matrix
# Out:
# {'Sheet2':    Unnamed: 0      강서구      금정구      기장군       남구       동구      동래구      부산진구  \
#  0         강서구  2698752    58589    11979    70535    99825   192947    219125
#  1         금정구   138397  4482891   208564    99217   526465  2166098   1217414
#  2         기장군     4583   129688  1867467    28954    53536   396961    491822
#  3          남구    57350    80233    36575  4688218   608780   195754   1814621
#  4          동구   219208   618871    79476   734176  3360432   949053   2388884
#  5         동래구   194350  2289364   457634   233324   760078  5024561   1931611
#  6        부산진구   339657  1296806   452747  1822945  2426762  2137568  10432204
#  7          북구   877968   378772   123901  1288385   571265  1259499   1754249
#  8         사상구   937870   145146    46025  1789804   323750   265754   2730134
#  9         사하구   773128   843636   125129   530719  2473973  1020783   2737532
#  10         서구   119139   316242    37419   276646  1245611   415722   1077626
# ...

# %%
#데이터 불러오기

metro_df = pd.read_excel('./2022_부산광역시지하철_이용객수요(OD).xlsx')
metro_df[[]]
# Out:
#        년도 origin_시도 origin_시군구 destination_시도 destination_시군구     통행량    통행시간  \
# 0    2022     부산광역시        강서구          부산광역시             강서구  2698752  20.33
# 1    2022     부산광역시        강서구          부산광역시             금정구   138397  39.34
# 2    2022     부산광역시        강서구          부산광역시             기장군     4583  83.31
# 3    2022     부산광역시        강서구          부산광역시              남구    57350  50.22
# 4    2022     부산광역시        강서구          부산광역시              동구   219208  44.01
# ..    ...       ...        ...            ...             ...      ...    ...
# 251  2022     부산광역시       해운대구          부산광역시             수영구  1506336  22.84
# 252  2022     부산광역시       해운대구          부산광역시             연제구  1479176  27.02
# 253  2022     부산광역시       해운대구          부산광역시             영도구    85090  53.23
# 254  2022     부산광역시       해운대구          부산광역시              중구   352495  49.13
# 255  2022     부산광역시       해운대구          부산광역시            해운대구  6703917  20.10
#
#      통행거리
# 0     3318
# ...

# %%
metro_df = metro_df[['origin_시군구', 'destination_시군구', '통행량']]
metro_df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-30-e675b12faccb> in <module>
# ----> 1 metro_df = metro_df[['origin_시군구', 'destination_시군구', '통행량']]
#       2 metro_df
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    3028             if is_iterator(key):
#    3029                 key = list(key)
# -> 3030             indexer = self.loc._get_listlike_indexer(key, axis=1, raise_missing=True)[1]
#    3031
#    3032         # take() does not accept boolean indexers
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1264             keyarr, indexer, new_indexer = ax._reindex_non_unique(keyarr)
#    1265
# -> 1266         self._validate_read_indexer(keyarr, indexer, axis, raise_missing=raise_missing)
# ...

# %%
metro_df['통행량']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '통행량'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-31-7f832e831cd2> in <module>
# ----> 1 metro_df['통행량']
#
# ...

# %%
g = nx.from_pandas_edgelist(df, 'from', 'to', create_using = nx.DiGraph())
nx.draw(g, with_labels=True)
